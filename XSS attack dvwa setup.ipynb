# %% [markdown]
# - Open XAMPP contorl panel and start the both Apache and Mysql services
#
# - After starting the Apache & Mysql serices in XAMPP,Download DVWA using following links  https://github.com/digininja/DVWA/archive/refs/heads/master.zip then extract the downloaded zip file
#
# - Now cut the DVWA folder then go to the XAMPP folder where XAMPP is install while installtion process and paste the DVWA folder inside the 'htdocs' folder of XAMPP.

# %% [markdown]
# - Open browser and type http://localhost/DVWA/ and you will get error that is shown in below :
#
#
#   ![image.png](attachment:image.png)
#
# - To slove the above error follow below steps :
#    - Open DVWA folder > config folder >  then rename the 'config.inc.php.dist' as config.inc.php > Click on 'Yes'.

# %% [markdown]
# - Open browser and type 'localhost/DVWA/login.php' and you will get error that is shown in below :
#
#   ![image.png](attachment:image.png)
#
# - To slove the above error follow below steps :
#    - Open DVWA folder > config folder >  then open 'config.inc.php' > find db_database ,db_user and db_password as a shown in below :
#
#   ![image-2.png](attachment:image-2.png)
#
#   - Open the XAMPP control panel > In MySQL module > click on 'Admin'> it will redirect to 'localhost/phpmyadmin' page.
#   - In that Create New database > give name as 'dvwa' > click on 'Create' button
#   - Now click on 'dvwa' database that is shown in left side > then Click on 'Privileges' (option palce on top side) > Click on 'Add user account'
#
#   - Now give user name that are shown in 'config.inc.php' file
#      - user name : dvwa
#      - Passoword : p@ssw0rd
#      - In Database for user account section > checked on 3rd option 'Grant all privileges on database dvwa'
#      - leave other thing as it is.
#      - Click on 'Go' (make sure that after click on go button and get message  'you have added a new user')
#   - Now go to the http://localhost/DVWA/login.php page > refresh it > you get login page of DVWA > Just click on login .
#
#   ![image-6.png](attachment:image-6.png)

# %% [markdown]
#   - After click on login button > http://localhost/DVWA/setup.php page will be open.
#   - Now click on 'Create/Reset Database' > it will show 'Setup successful'.
#
#   ![image.png](attachment:image.png)
#
#   - Now open 'http://localhost/DVWA/login.php' page > Enter login details
#     - Username : admin
#     - Password : password
#   - As result it will open ' http://localhost/DVWA/index.php '
#
#   - Go to http://localhost/DVWA/setup.php  page > in that it will show
#     - allow_url_include : **Disabled**
#     - gd : **Missing Only an issue if you want to play with captches**
#     ![image-2.png](attachment:image-2.png)
#    - To slove the above error follow below steps :
#        - Open the XAMPP control panel > In Apache module > click on 'config'> select option 'PHP(php.ini)' and open this file
#        - In file Search for 'allow_url_include' (using ctrl+f in notepad) and it is by default is 'Off' we need to change it to 'On'(as shown in below image).
#
#        ![image-3.png](attachment:image-3.png)
#        - Now for 2nd error (gd) ,return search in same file 'gd' just remove the semicolon before the 'extension=gd' as shown in below images :
#     ![image-5.png](attachment:image-5.png)
#     ![image-4.png](attachment:image-4.png)

# %% [markdown]
#    - After changes done in the 'PHP(php.ini)' file then save it and only stop the apache module and again restart the module and check the page http://localhost/DVWA/setup.php
#     ![image.png](attachment:image.png)
